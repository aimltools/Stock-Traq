# %% [markdown]
# <a href="https://colab.research.google.com/github/aimltools/Stock-Traq/blob/main/stockAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd

# %%
tickers=['ADANIENT.NS', 'ADANIPORTS.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS', 'BAJAJFINSV.NS',
         'BEL.NS', 'BHARTIARTL.NS', 'CIPLA.NS', 'COALINDIA.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'GRASIM.NS', 'HCLTECH.NS',
         'HDFCBANK.NS', 'HDFCLIFE.NS', 'HEROMOTOCO.NS', 'HINDALCO.NS', 'HINDUNILVR.NS', 'ICICIBANK.NS', 'INDUSINDBK.NS', 'INFY.NS', 'ITC.NS',
         'JIOFIN.NS', 'JSWSTEEL.NS', 'KOTAKBANK.NS', 'LT.NS', 'M&M.NS', 'MARUTI.NS', 'NESTLEIND.NS', 'NTPC.NS', 'ONGC.NS', 'POWERGRID.NS',
         'RELIANCE.NS', 'SBILIFE.NS', 'SHRIRAMFIN.NS', 'SBIN.NS', 'SUNPHARMA.NS', 'TCS.NS', 'TATACONSUM.NS', 'TATAMOTORS.NS', 'TATASTEEL.NS',
         'TECHM.NS', 'TITAN.NS', 'TRENT.NS', 'ULTRACEMCO.NS', 'WIPRO.NS'
]

stockData=yf.download(tickers, start='2024-01-01', end='2025-01-01', group_by='ticker')
# Out:
# /tmp/ipython-input-2-2749471555.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stockData=yf.download(tickers, start='2024-01-01', end='2025-01-01', group_by='ticker')
# [*********************100%***********************]  49 of 49 completed

# %%
stockData.head(10)
# Out:
# Ticker         TECHM.NS                                                  \
# Price              Open         High          Low        Close   Volume
# Date
# 2024-01-01  1238.718229  1268.688835  1231.176936  1262.217896  1776828
# 2024-01-02  1263.044904  1264.115257  1238.572168  1243.680786  1615064
# 2024-01-03  1230.933755  1239.691386  1206.607000  1210.693848  2231707
# 2024-01-04  1216.434866  1220.910964  1198.530353  1213.904907  3355191
# 2024-01-05  1221.105711  1237.599202  1212.007529  1214.683472  1756868
# 2024-01-08  1216.532233  1220.473214  1188.507884  1195.854492  1320667
# 2024-01-09  1207.142213  1217.505315  1199.406234  1202.374146   994439
# 2024-01-10  1203.201256  1212.883256  1195.222128  1207.482788   808638
# 2024-01-11  1207.482688  1227.819877  1207.482688  1215.753784   930492
# 2024-01-12  1237.550670  1276.424775  1232.879886  1272.824463  5023455
#
# Ticker           TCS.NS                                                  ...  \
# Price              Open         High          Low        Close   Volume  ...
# Date                                                                     ...
# 2024-01-01  3636.713743  3677.015057  3620.401307  3656.960449   825907  ...
# 2024-01-02  3656.960202  3656.960202  3614.883621  3630.188477  1344068  ...
# 2024-01-03  3614.643771  3619.297707  3537.927394  3542.437256  1803075  ...
# 2024-01-04  3552.032738  3568.585062  3503.335322  3518.496338  3598144  ...
# 2024-01-05  3526.364785  3596.172414  3526.220945  3586.720703  1963127  ...
# 2024-01-08  3586.720340  3588.495610  3523.869491  3529.531006  1067805  ...
# 2024-01-09  3559.901235  3600.586510  3533.801384  3540.662109  1370944  ...
# 2024-01-10  3540.757943  3578.420477  3538.838833  3562.875732  1292227  ...
# 2024-01-11  3573.382670  3620.400863  3557.070235  3584.465576  1777909  ...
# 2024-01-12  3692.367693  3747.302217  3667.035534  3725.760254  6813450  ...
#
# Ticker            LT.NS                                                  \
# Price              Open         High          Low        Close   Volume
# Date
# 2024-01-01  3477.968452  3477.968452  3436.730293  3465.631348   777080
# 2024-01-02  3465.238288  3465.631405  3373.767078  3379.763672  1511464
# 2024-01-03  3374.750202  3407.042912  3353.713405  3381.975586  1283859
# 2024-01-04  3382.663491  3421.050952  3364.919709  3400.013916  1651616
# 2024-01-05  3406.157716  3494.679823  3401.291754  3462.141357  2069018
# 2024-01-08  3479.934688  3499.546137  3430.783069  3441.694824  1993855
# 2024-01-09  3467.597590  3532.772686  3460.372446  3495.614014  1807271
# 2024-01-10  3489.715510  3498.562801  3460.273740  3485.341064  1534821
# 2024-01-11  3485.341273  3499.152926  3441.154016  3445.381104  1105348
# 2024-01-12  3445.577538  3517.928574  3434.764182  3508.245850  1782631
#
# Ticker          BEL.NS
# Price             Open        High         Low       Close    Volume
# Date
# 2024-01-01  181.942108  184.108083  181.597515  182.089783  18008785
# 2024-01-02  183.123551  183.320455  176.970206  179.333084  22790965
# 2024-01-03  179.529999  181.843647  177.807062  179.529999  18738690
# 2024-01-04  179.677694  184.748045  179.677694  184.009644  25403124
# 2024-01-05  184.797247  185.732552  181.203700  183.074310  22023938
# 2024-01-08  183.861930  184.600332  180.366828  180.760651  11472441
# 2024-01-09  182.040552  183.812718  181.351381  181.794418  11550790
# 2024-01-10  181.548282  183.123544  179.234633  182.729736   8701594
# 2024-01-11  184.108081  184.748023  180.957572  181.499069  10942508
# 2024-01-12  182.483612  182.631287  180.268408  180.662216   8853157
#
# [10 rows x 245 columns]

# %%
stockData.describe()
# Out:
# Ticker     TECHM.NS                                                       \
# Price          Open         High          Low        Close        Volume
# count    246.000000   246.000000   246.000000   246.000000  2.460000e+02
# mean    1444.121434  1460.820818  1426.848443  1443.642538  2.207446e+06
# std      195.617144   198.818038   193.836539   196.697737  1.666034e+06
# min     1131.729206  1161.407839  1131.631804  1147.882202  2.492360e+05
# 25%     1257.668907  1271.267600  1240.202158  1257.535095  1.374404e+06
# 50%     1427.007410  1434.694569  1406.791825  1422.969116  1.831499e+06
# 75%     1624.409142  1644.144396  1604.673857  1627.853241  2.502291e+06
# max     1797.000000  1807.699951  1775.599976  1796.400024  2.043193e+07
#
# Ticker       TCS.NS                                                       ...  \
# Price          Open         High          Low        Close        Volume  ...
# count    246.000000   246.000000   246.000000   246.000000  2.460000e+02  ...
# mean    3968.814660  4007.877249  3933.405748  3968.718897  2.413507e+06  ...
# std      234.334725   235.927487   232.096458   234.639591  1.431049e+06  ...
# min     3526.364785  3568.585062  3487.374719  3518.496338  1.548950e+05  ...
# 25%     3756.881750  3795.317761  3729.726157  3748.551880  1.637576e+06  ...
# 50%     3957.717631  3997.833920  3917.268951  3957.672241  2.054520e+06  ...
# 75%     4147.998589  4183.793150  4124.056139  4158.230103  2.844210e+06  ...
# max     4453.651401  4469.467702  4391.362570  4431.997070  1.350916e+07  ...
#
# Ticker        LT.NS                                                       \
# Price          Open         High          Low        Close        Volume
# count    246.000000   246.000000   246.000000   246.000000  2.460000e+02
# mean    3549.057228  3584.277702  3508.583989  3545.656215  2.546128e+06
# std      135.870189   134.892937   137.900359   135.815654  1.616808e+06
# min     3211.615867  3250.052337  3121.176860  3215.941162  2.127960e+05
# 25%     3477.667473  3521.049032  3436.784202  3472.797546  1.637806e+06
# 50%     3552.768028  3588.226081  3517.197499  3551.351929  2.110519e+06
# 75%     3626.181104  3659.120172  3586.550714  3617.821472  2.893096e+06
# max     3918.455212  3926.876671  3865.944886  3910.826416  1.212057e+07
#
# Ticker      BEL.NS
# Price         Open        High         Low       Close        Volume
# count   246.000000  246.000000  246.000000  246.000000  2.460000e+02
# mean    261.163995  264.507496  256.325108  260.485575  3.060982e+07
# std      48.309432   48.607715   47.607349   47.976832  2.814094e+07
# min     172.701693  174.826486  169.736857  172.602859  5.265231e+06
# 25%     215.070782  221.135439  212.258789  218.668331  1.612603e+07
# 50%     282.997127  286.538011  278.796523  282.485458  2.392726e+07
# 75%     299.325904  302.432031  294.444220  298.630333  3.469536e+07
# max     337.213886  337.709789  330.271249  332.750763  2.680527e+08
#
# [8 rows x 245 columns]

# %%
stockData.isnull().sum()
# Out:
# Ticker    Price
# TECHM.NS  Open      0
#           High      0
#           Low       0
#           Close     0
#           Volume    0
#                    ..
# BEL.NS    Open      0
#           High      0
#           Low       0
#           Close     0
#           Volume    0
# Length: 245, dtype: int64

# %%
dfs=[]
for ticker in tickers:
  df=stockData[ticker].copy()
  df['Ticker']= ticker
  df=df.reset_index()
  dfs.append(df)

final_df= pd.concat(dfs, ignore_index=True)
final_df.to_csv('nifty50_fullList', index=False)

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'nifty50_fullList', 'sample_data']

# %%
df1=pd.read_csv('nifty50_fullList')
df1.head()
# Out:
#          Date         Open         High          Low        Close      Volume  \
# 0  2024-01-01  2849.693106  2944.306504  2839.452475  2914.533691   2898619.0
# 1  2024-01-02  2919.329330  2945.505334  2838.403363  2929.719727   2671368.0
# 2  2024-01-03  3044.215157  3196.076234  2952.898790  3000.255371  19725411.0
# 3  2024-01-04  3036.621858  3041.667291  2987.267108  2995.559570   2975620.0
# 4  2024-01-05  3007.199087  3064.096990  2978.375600  3003.852295   3219949.0
#
#         Ticker
# 0  ADANIENT.NS
# 1  ADANIENT.NS
# 2  ADANIENT.NS
# 3  ADANIENT.NS
# 4  ADANIENT.NS

# %%
print(df1.shape)
# Out:
# (12054, 7)

# %%
tickers_nan=df1.groupby('Ticker').apply(lambda x: x.isnull().any().any())
tickers_nan= tickers_nan[tickers_nan].index.tolist()

print("tickers with nan values are", tickers_nan)
# Out:
# tickers with nan values are ['JIOFIN.NS']
# /tmp/ipython-input-10-2795476278.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tickers_nan=df1.groupby('Ticker').apply(lambda x: x.isnull().any().any())

# %%
print(df1['Ticker'].unique())
# Out:
# ['ADANIENT.NS' 'ADANIPORTS.NS' 'APOLLOHOSP.NS' 'ASIANPAINT.NS'
#  'AXISBANK.NS' 'BAJAJ-AUTO.NS' 'BAJFINANCE.NS' 'BAJAJFINSV.NS' 'BEL.NS'
#  'BHARTIARTL.NS' 'CIPLA.NS' 'COALINDIA.NS' 'DRREDDY.NS' 'EICHERMOT.NS'
#  'GRASIM.NS' 'HCLTECH.NS' 'HDFCBANK.NS' 'HDFCLIFE.NS' 'HEROMOTOCO.NS'
#  'HINDALCO.NS' 'HINDUNILVR.NS' 'ICICIBANK.NS' 'INDUSINDBK.NS' 'INFY.NS'
#  'ITC.NS' 'JIOFIN.NS' 'JSWSTEEL.NS' 'KOTAKBANK.NS' 'LT.NS' 'M&M.NS'
#  'MARUTI.NS' 'NESTLEIND.NS' 'NTPC.NS' 'ONGC.NS' 'POWERGRID.NS'
#  'RELIANCE.NS' 'SBILIFE.NS' 'SHRIRAMFIN.NS' 'SBIN.NS' 'SUNPHARMA.NS'
#  'TCS.NS' 'TATACONSUM.NS' 'TATAMOTORS.NS' 'TATASTEEL.NS' 'TECHM.NS'
#  'TITAN.NS' 'TRENT.NS' 'ULTRACEMCO.NS' 'WIPRO.NS']

# %%
df1.iloc[100:200]
# Out:
#            Date         Open         High          Low        Close  \
# 100  2024-05-31  3222.302173  3431.310918  3222.302173  3408.232178
# 101  2024-06-03  3721.595570  3740.478199  3582.772611  3641.918457
# 102  2024-06-04  3516.783096  3516.783096  2731.451413  2938.562012
# 103  2024-06-05  3027.230597  3147.120918  2747.486516  3112.502686
# 104  2024-06-06  3181.089887  3219.454692  3134.282609  3182.738281
# ..          ...          ...          ...          ...          ...
# 195  2024-10-17  3088.370723  3098.415636  2991.470322  3012.209717
# 196  2024-10-18  2988.471953  3030.150593  2966.583243  3000.465820
# 197  2024-10-21  3003.614187  3013.409228  2915.459309  2936.148682
# 198  2024-10-22  2936.498522  2953.489834  2816.559849  2822.356934
# 199  2024-10-23  2839.398170  2877.528574  2818.658775  2834.100830
#
#          Volume       Ticker
# 100   6384589.0  ADANIENT.NS
# 101   8511359.0  ADANIENT.NS
# 102  20306909.0  ADANIENT.NS
# 103   8778345.0  ADANIENT.NS
# 104   5873271.0  ADANIENT.NS
# ..          ...          ...
# 195   2655289.0  ADANIENT.NS
# 196    796339.0  ADANIENT.NS
# 197   1051690.0  ADANIENT.NS
# 198   1209732.0  ADANIENT.NS
# 199   1270530.0  ADANIENT.NS
#
# [100 rows x 7 columns]

# %%
print(df1.isnull().sum())
# Out:
# Date      0
# Open      4
# High      4
# Low       4
# Close     4
# Volume    4
# Ticker    0
# dtype: int64

# %%
df1.shape[0]
# Out:
# 12054

# %%
print(df1.shape)
# Out:
# (12054, 7)

# %%
df1= df1.sort_values(['Ticker', 'Date'])

df1[['High','Low','Volume','Close']]=df1.groupby('Ticker')[['High','Low','Volume','Close']].ffill()

df1['Open']= df1['Open'].fillna(df1.groupby('Ticker')['Close'].shift(1))

print(df1.isnull().sum())
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# Ticker    0
# dtype: int64

# %%
df1=df1.ffill().bfill()

# %%
print(df1.shape)
# Out:
# (12054, 7)

# %%
print(df1.isnull().sum())
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# Ticker    0
# dtype: int64

# %%
df1.describe()
# Out:
#                Open          High           Low         Close        Volume
# count  12054.000000  12054.000000  12054.000000  12054.000000  1.205400e+04
# mean    2292.041620   2316.577088   2264.496529   2290.282479  7.944581e+06
# std     2579.797133   2607.503433   2549.526476   2578.625049  1.287027e+07
# min      124.720028    126.683755    122.804212    124.624245  0.000000e+00
# 25%      697.053778    706.447929    687.995156    696.255493  1.188852e+06
# 50%     1456.753019   1470.552679   1440.771274   1455.548462  3.201453e+06
# 75%     2781.881941   2810.158244   2750.134505   2780.950012  1.023534e+07
# max    13383.000000  13551.996884  13274.450195  13495.599609  2.700771e+08

# %%
import seaborn as sns
columns = ['Open', 'High', 'Low', 'Close', 'Volume']

for col in columns:
  plt.figure(figsize=(8,4))
  sns.boxplot(x=df[col])
  plt.title(f'Boxplot of {col}')
  plt.show()

# %%
print(df1.shape)
# Out:
# (12054, 7)

# %%
df1=df1.drop_duplicates()

# %%
df1.describe()
# Out:
#                Open          High           Low         Close        Volume
# count  12054.000000  12054.000000  12054.000000  12054.000000  1.205400e+04
# mean    2292.041620   2316.577088   2264.496529   2290.282479  7.944581e+06
# std     2579.797133   2607.503433   2549.526476   2578.625049  1.287027e+07
# min      124.720028    126.683755    122.804212    124.624245  0.000000e+00
# 25%      697.053778    706.447929    687.995156    696.255493  1.188852e+06
# 50%     1456.753019   1470.552679   1440.771274   1455.548462  3.201453e+06
# 75%     2781.881941   2810.158244   2750.134505   2780.950012  1.023534e+07
# max    13383.000000  13551.996884  13274.450195  13495.599609  2.700771e+08

# %%
print(df1.shape)
# Out:
# (12054, 7)

# %%
from sklearn.preprocessing import StandardScaler

columns_to_scale=['Open', 'High', 'Low', 'Close', 'Volume']
scaler= StandardScaler()

df1[columns_to_scale]= scaler.fit_transform(df1[columns_to_scale])

# %%
print(df1.shape)
# Out:
# (12054, 7)

# %%
df1.describe()
# Out:
#                Open          High           Low         Close        Volume
# count  1.205400e+04  1.205400e+04  1.205400e+04  1.205400e+04  1.205400e+04
# mean   3.772585e-17  8.959888e-17 -8.016742e-17 -7.073596e-17  1.886292e-17
# std    1.000041e+00  1.000041e+00  1.000041e+00  1.000041e+00  1.000041e+00
# min   -8.401480e-01 -8.398778e-01 -8.400702e-01 -8.398848e-01 -6.173071e-01
# 25%   -6.182866e-01 -6.175240e-01 -6.183763e-01 -6.181950e-01 -5.249312e-01
# 50%   -3.237942e-01 -3.244711e-01 -3.231029e-01 -3.237263e-01 -3.685489e-01
# 75%    1.898834e-01  1.893005e-01  1.904895e-01  1.902905e-01  1.779954e-01
# max    4.299337e+00  4.309059e+00  4.318610e+00  4.345642e+00  2.036813e+01

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

df1['Ticker']= le.fit_transform( df1['Ticker'])

# %%
df1['Future_Close']= df1.groupby('Ticker')['Close'].shift(-1)
df1['Return']= (df1['Future_Close']-df1['Close'])/df1['Close']

def label_action(x):
  if x>0.02:
    return 'Buy'
  elif x<-0.02:
    return 'Sell'
  else:
    return 'Hold'

df1['Target']= df1['Return'].apply(label_action)

# %%
print(df1.shape)
# Out:
# (12054, 10)

# %%
import numpy as np
def compute_rsi(close_prices, period=14):
  delta= close_prices.diff()
  gain= np.where(delta>0, delta, 0)
  loss=np.where(delta<0, -delta, 0)
  avg_gain= pd.Series(gain).rolling(period).mean()
  avg_loss= pd.Series(loss).rolling(period).mean()
  rs=avg_gain/ avg_loss
  return 100 - (100/(1+rs))


def compute_bollinger_bands(close_prices, period=20, std_dev=2):
  sma= close_prices.rolling(period).mean()
  std= close_prices.rolling(period).std()
  upper_band= sma+(std_dev*std)
  lower_band= sma-(std_dev*std)
  return sma, upper_band, lower_band


def compute_macd(close_prices, fast=12, slow=26, signal=9):
  ema_fast= close_prices.ewm(span=fast, adjust=False).mean()
  ema_slow= close_prices.ewm(span=slow, adjust=False).mean()
  macd_line= ema_fast- ema_slow
  signal_line= macd_line.ewm(span=signal, adjust=False).mean()
  histogram= macd_line - signal_line
  return macd_line, signal_line, histogram


def compute_ema(prices, period):
    return prices.ewm(span=period, adjust=False).mean()


def compute_atr(high, low, close, period=14):
    high_low = high - low
    high_close = (high - close.shift()).abs()
    low_close = (low - close.shift()).abs()
    tr = pd.concat([high_low, high_close, low_close], axis=1).max(axis=1)
    atr = tr.rolling(period).mean()
    return atr


def compute_cci(high, low, close, period=20):
    tp = (high + low + close) / 3
    sma = tp.rolling(period).mean()
    mad = tp.rolling(period).apply(lambda x: np.mean(np.abs(x - np.mean(x))))
    cci = (tp - sma) / (0.015 * mad)
    return cci

def compute_roc(close, period=10):
    roc = (close - close.shift(period)) / close.shift(period) * 100
    return roc


def compute_mfi(high, low, close, volume, period=14):
    tp = (high + low + close) / 3
    mf = tp * volume
    pos_mf = np.where(tp > tp.shift(1), mf, 0)
    neg_mf = np.where(tp < tp.shift(1), mf, 0)

    pos_mf_sum = pd.Series(pos_mf).rolling(period).sum()
    neg_mf_sum = pd.Series(neg_mf).rolling(period).sum()

    mfi = 100 - (100 / (1 + (pos_mf_sum / neg_mf_sum)))
    return mfi


def compute_obv(close, volume):
    obv = [0]
    for i in range(1, len(close)):
        if close[i] > close[i-1]:
            obv.append(obv[-1] + volume[i])
        elif close[i] < close[i-1]:
            obv.append(obv[-1] - volume[i])
        else:
            obv.append(obv[-1])
    return pd.Series(obv, index=close.index)


    df1.dropna(inplace=True)

# %%
df1['RSI']= compute_rsi(df1['Close'])

df1['BB_Middle'], df1['BB_Upper'], df1['BB_Lower'] = compute_bollinger_bands(df1['Close'])

df1['MACD'], df1['Signal'], df1['Histogram'] = compute_macd(df1['Close'])

df1['SMA_50'] = df1['Close'].rolling(50).mean()
df1['EMA_20'] = df1['Close'].ewm(span=20, adjust=False).mean()

df1['OBV'] = (np.sign(df1['Close'].diff())*df1['Volume']).fillna(0).cumsum()
df1['VWAP'] = (df1['Close']* df1['Volume']).cumsum()/ df1['Volume'].cumsum()

df1['ATR_14'] = compute_atr(df1['High'], df1['Low'], df1['Close'])
df1['CCI_20'] = compute_cci(df1['High'], df1['Low'], df1['Close'])

df1['ROC_10'] = compute_roc(df1['Close'])
df1['MFI_14'] = compute_mfi(df1['High'], df1['Low'], df1['Close'], df1['Volume'])
# Out:
# /tmp/ipython-input-83-1239196397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['RSI']= compute_rsi(df1['Close'])
# /tmp/ipython-input-83-1239196397.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['BB_Middle'], df1['BB_Upper'], df1['BB_Lower'] = compute_bollinger_bands(df1['Close'])
# /tmp/ipython-input-83-1239196397.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['MACD'], df1['Signal'], df1['Histogram'] = compute_macd(df1['Close'])
# /tmp/ipython-input-83-1239196397.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['SMA_50'] = df1['Close'].rolling(50).mean()
# /tmp/ipython-input-83-1239196397.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['EMA_20'] = df1['Close'].ewm(span=20, adjust=False).mean()
# /tmp/ipython-input-83-1239196397.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['OBV'] = (np.sign(df1['Close'].diff())*df1['Volume']).fillna(0).cumsum()
# /tmp/ipython-input-83-1239196397.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['VWAP'] = (df1['Close']* df1['Volume']).cumsum()/ df1['Volume'].cumsum()
# /tmp/ipython-input-83-1239196397.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['ATR_14'] = compute_atr(df1['High'], df1['Low'], df1['Close'])
# /tmp/ipython-input-83-1239196397.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['CCI_20'] = compute_cci(df1['High'], df1['Low'], df1['Close'])
# /tmp/ipython-input-83-1239196397.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['ROC_10'] = compute_roc(df1['Close'])
# /tmp/ipython-input-83-1239196397.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['MFI_14'] = compute_mfi(df1['High'], df1['Low'], df1['Close'], df1['Volume'])

# %%
df1['RSI_1'] = df1['RSI'].shift(1)
df1['MACD_1'] = df1['MACD'].shift(1)
df1['Return_1'] = df1['Close'].pct_change(1)
df1['Return_5'] = df1['Close'].pct_change(5)
df1['Rolling_Mean_5'] = df1['Close'].rolling(5).mean()
df1['Rolling_Std_5'] = df1['Close'].rolling(5).std()

# Update your feature_columns list
feature_columns = [
    'RSI', 'BB_Middle', 'BB_Upper', 'BB_Lower',
    'MACD', 'Signal', 'Histogram',
    'RSI_1', 'MACD_1', 'Return_1', 'Return_5', 'Rolling_Mean_5', 'Rolling_Std_5', 'ATR_14', 'CCI_20','ROC_10','MFI_14'
]

# Drop NaNs after all features are created

df1 = df1.dropna(subset=[col for col in feature_columns if col in df1.columns])
# Out:
# /tmp/ipython-input-84-2344406246.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['RSI_1'] = df1['RSI'].shift(1)
# /tmp/ipython-input-84-2344406246.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['MACD_1'] = df1['MACD'].shift(1)
# /tmp/ipython-input-84-2344406246.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Return_1'] = df1['Close'].pct_change(1)
# /tmp/ipython-input-84-2344406246.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Return_5'] = df1['Close'].pct_change(5)
# /tmp/ipython-input-84-2344406246.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Rolling_Mean_5'] = df1['Close'].rolling(5).mean()
# /tmp/ipython-input-84-2344406246.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Rolling_Std_5'] = df1['Close'].rolling(5).std()

# %%
print(df1[feature_columns].isna().sum())
# Out:
# RSI               0
# BB_Middle         0
# BB_Upper          0
# BB_Lower          0
# MACD              0
# Signal            0
# Histogram         0
# RSI_1             0
# MACD_1            0
# Return_1          0
# Return_5          0
# Rolling_Mean_5    0
# Rolling_Std_5     0
# ATR_14            0
# CCI_20            0
# ROC_10            0
# MFI_14            0
# dtype: int64

# %%
print(df1.shape)
# Out:
# (12035, 31)

# %%
df1['Return'] = df1['Close'].pct_change().shift(-1)
df1['Target'] = (df1['Return'] > 0.003).astype(int)


X= df1[feature_columns]
y= df1['Target']

# %%
corr_matrix = X[feature_columns].corr().abs()

upper= corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(bool))

to_drop= [column for column in upper.columns if any(upper[column]>0.95)]

# %%
print(df1[feature_columns].isna().sum())
# Out:
# RSI               0
# BB_Middle         0
# BB_Upper          0
# BB_Lower          0
# MACD              0
# Signal            0
# Histogram         0
# RSI_1             0
# MACD_1            0
# Return_1          0
# Return_5          0
# Rolling_Mean_5    0
# Rolling_Std_5     0
# ATR_14            0
# CCI_20            0
# ROC_10            0
# MFI_14            0
# dtype: int64

# %%
print(df1[feature_columns].shape)
# Out:
# (11698, 17)

# %%
print(X.shape)
print(y.shape)
# Out:
# (12035, 17)
# (12035,)

# %%
X= df1[feature_columns]
y= df1.loc[X.index, 'Target']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle= False, random_state=42)



from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_test_scaled= scaler.fit_transform(X_test)
X_train_scaled= scaler.fit_transform(X_train)

print(X.shape)
print(y.shape)
# Out:
# (11698, 17)
# (11698,)

# %%
print(y.shape)
# Out:
# (12035,)

# %%
print(y.value_counts())
# Out:
# Target
# 1    6059
# 0    5946
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report


model= LogisticRegression(max_iter=1000, random_state=42)
model.fit(X_train_scaled, y_train)

y_pred=model.predict(X_test_scaled)
print("accuracy:", accuracy_score(y_test, y_pred))
# Out:
# accuracy: 0.6068376068376068

# %%
from xgboost import XGBClassifier
model = XGBClassifier(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric='logloss'
)
model.fit(X_train_scaled, y_train)

y_pred= model.predict(X_test_scaled)

print("accuracy", accuracy_score(y_test, y_pred))
# Out:
# accuracy 0.6341880341880342

# %%
from xgboost import XGBClassifier
model = XGBClassifier(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=5,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0.2,
    use_label_encoder=False,
    random_state= 42,
    eval_metric='logloss'
)
model.fit(X_train_scaled, y_train)

y_pred= model.predict(X_test_scaled)

print("accuracy", accuracy_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [11:14:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# accuracy 0.632051282051282

# %%
from xgboost import XGBClassifier
model = XGBClassifier(
    n_estimators=300,
    learning_rate=0.1,
    max_depth=6,
    subsample=0.9,
    colsample_bytree=0.8,
    gamma=0,
    use_label_encoder=False,
    random_state= 42,
    eval_metric='logloss'
)
model.fit(X_train_scaled, y_train)

y_pred= model.predict(X_test_scaled)

print("accuracy", accuracy_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [11:14:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# accuracy 0.6183760683760684

# %%
from lightgbm import LGBMClassifier

model3= LGBMClassifier(random_state=42)
model3.fit(X_train_scaled, y_train)
y_pred= model.predict(X_test_scaled)

print("accuracy", accuracy_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 3391, number of negative: 5967
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000572 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4335
# [LightGBM] [Info] Number of data points in the train set: 9358, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.362364 -> initscore=-0.565119
# [LightGBM] [Info] Start training from score -0.565119
# accuracy 0.6183760683760684

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV

# Define the base model
model = LGBMClassifier(random_state=42)

# Define parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.01, 0.05, 0.1],
    'num_leaves': [15, 31, 63],
}

# Create the GridSearchCV object
grid_search = GridSearchCV(estimator=model,
                           param_grid=param_grid,
                           cv=5,
                           scoring='accuracy',
                           verbose=1,
                           n_jobs=-1)

# Fit the grid search
grid_search.fit(X_train_scaled, y_train)
# Best model
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_scaled)

from sklearn.metrics import accuracy_score
print("Best Parameters:", grid_search.best_params_)
print("Accuracy on Test Set:", accuracy_score(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [LightGBM] [Info] Number of positive: 3391, number of negative: 5967
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000568 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4335
# [LightGBM] [Info] Number of data points in the train set: 9358, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.362364 -> initscore=-0.565119
# [LightGBM] [Info] Start training from score -0.565119
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Best Parameters: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 15}
# Accuracy on Test Set: 0.6200854700854701
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, classification_report

# Replace the values below with the actual best params from your output
best_params = {
    'learning_rate': 0.01,
    'max_depth': 3,
    'n_estimators': 50,
    'num_leaves': 15
}

final_model = LGBMClassifier(**best_params, random_state=42)
final_model.fit(X_train_scaled, y_train)

# Predict
y_pred = final_model.predict(X_test_scaled)

# Evaluate
print("Final Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 3391, number of negative: 5967
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000558 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4335
# [LightGBM] [Info] Number of data points in the train set: 9358, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.362364 -> initscore=-0.565119
# [LightGBM] [Info] Start training from score -0.565119
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Final Accuracy: 0.6200854700854701
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77      1451
#            1       0.00      0.00      0.00       889
#
#     accuracy                           0.62      2340
#    macro avg       0.31      0.50      0.38      2340
# weighted avg       0.38      0.62      0.47      2340
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.model_selection import RandomizedSearchCV
from lightgbm import LGBMClassifier

param_dist = {
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1],
    'num_leaves': [15, 31]
}

search = RandomizedSearchCV(
    estimator=LGBMClassifier(random_state=42),
    param_distributions=param_dist,
    n_iter=10,  # Try just 10 combinations
    scoring='accuracy',
    cv=3,       # Reduce to 3-fold CV
    verbose=1,
    n_jobs=-1,
    random_state=42
)

search.fit(X_train_scaled, y_train)
print("Best Params:", search.best_params_)
print("Final Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [LightGBM] [Info] Number of positive: 3727, number of negative: 5631
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000575 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4335
# [LightGBM] [Info] Number of data points in the train set: 9358, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.398269 -> initscore=-0.412683
# [LightGBM] [Info] Start training from score -0.412683
# Best Params: {'num_leaves': 15, 'n_estimators': 50, 'max_depth': 7, 'learning_rate': 0.01}
# Final Accuracy: 0.5927350427350427
#               precision    recall  f1-score   support
#
#            0       0.59      1.00      0.74      1387
#            1       0.00      0.00      0.00       953
#
#     accuracy                           0.59      2340
#    macro avg       0.30      0.50      0.37      2340
# weighted avg       0.35      0.59      0.44      2340
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.1.2)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 6.7 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score, classification_report

model=CatBoostClassifier(verbose=0, random_state=42)
model.fit(X_train_scaled, y_train)

y_pred=model.predict(X_test_scaled)

print("accuracy", accuracy_score(y_test, y_pred))
# Out:
# accuracy 0.6106837606837607

# %%
model = CatBoostClassifier(
    iterations=375,
    learning_rate=0.13,
    depth=4,
    verbose=0,
    random_state=42
)

model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
print(" Accuracy:", accuracy_score(y_test, y_pred))
# Out:
#  Accuracy: 0.6089743589743589

# %%
from sklearn.ensemble import VotingClassifier

ensemble = VotingClassifier(estimators=[
    ('cat', CatBoostClassifier(verbose=0)),
    ('xgb', XGBClassifier(verbosity=0)),
    ('rf', RandomForestClassifier())
], voting='soft')

ensemble.fit(X_train_scaled, y_train)
y_pred = ensemble.predict(X_test_scaled)

print(" Accuracy:", accuracy_score(y_test, y_pred))
# Out:
#  Accuracy: 0.6051282051282051
